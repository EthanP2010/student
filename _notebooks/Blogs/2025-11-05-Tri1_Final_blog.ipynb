# %% [markdown]
# ---
# layout: post
# breadcrumb: True
# title: Trimester 1 Final Blog
# description: Retrospective blog about all of tri 1
# permalink: /blogs/Final-Tri1-blog/
# categories: [CSP, Final, Tri 1]
# author: Ethan Patel
# ---

# %% [markdown]
# ## Beginning vs Now

# %% [markdown]
# | Beginning | Now |
# | :------------ | :------------ |
# | Didn't know how to access terminal   | Access terminal by doing a spotlight search   |
# | Didn't know anything about Github or VSCode   | Can easily access VSCode and Github on a regular basis   |
# | Couldn't make a PR   | Have made many PRs to contribute to pages   |
# | Uncofident and unknowledgeable about coding basics   | Know and understand variables, data types, functions, etc.   |
# | Didn't know too many people in class   | Met more people and became closer with new people   |

# %% [markdown]
# ---

# %% [markdown]
# ## Overview of the three sprints

# %% [markdown]
# ### Sprint 1: Tools

# %% [markdown]
# This sprint was, without a doubt, the most **difficult** for me. I was frustrated as many of my tools were not working. Eventually, through **patience and perseverance**, I completed the main objective of the sprint and learned how to install and use my tools. My knowledge of using these tools increased throughout this trimester, through **new experiences** that helped strengthen my knowledge.

# %% [markdown]
# **These steps will forever be cemented in my brain when cloning a repo for VSCode:**

# %% [markdown]
#   `cd`
#
#   `cd EthanP2010` --> My directory
#
#   `git clone[link]` --> link of repo from github
#
#   `./scripts/venv.sh` --> Activate the virtual environment
#
#   `source venv/bin/activate` --> See venv in path
#
#   `bundle install` --> Ensure Ruby gems for GitHub Pages is installed in (venv)
#
#   `code .` --> Open the project in VS Code

# %% [markdown]
#  **3 Key things:**
#  1. Setting up a new repo in VSCode
#  2. Never paste in multiple commands at once (Go in order)
#  3. Testing if my changes worked using `make` and commiting them in VSCode

# %% [markdown]
# ### Sprint 2: Fundamentals of JavaScript/Python

# %% [markdown]
# In this Sprint, I learned the value of **teamwork and communication** in teams. My group and I did well in this and we were able to create our lessons in a timely manner. I also learned the use of **AI** to troubleshoot problems with my code.

# %% [markdown]
# Key takeaways:
# 1. Creating a fun MCQ that I think the class really enjoyed
# 2. Working on a team repo for the first time and using it to collaborate
# 3. The fun in calling on facetime and working together with Tanay and Neil

# %% [markdown]
# ### Sprint 3: West Coast Quest

# %% [markdown]
# This sprint had many ups and downs. I had to stay up late working on issues with code but had fun along the way. It got off to a slow start with brainstorming troubles but I eventually we settled on an idea. Also, many people in my group progressed in knowledge of Github and VSCode throughout this sprint incluidng me.

# %% [markdown]
# **3 takeaways:**
# 1. To **not give up** when things become hard and issues occur
# 2. I had more knowledge of LA sports (the submodule I worked on) as well as the other 3 cities
# 3. When presenting, **do not** crowd the screen

# %% [markdown]
# ---

# %% [markdown]
# ## Night at the Museum

# %% [markdown]
# I think N@tM went well overall and for our group. We were able to display our learning and achievements to those who came, including my parents. I also liked how the CSA students could see our work and review it.

# %% [markdown]
# ### Improvements for next time:

# %% [markdown]
# - **Not crowding** the screen (fixed this midway through the event)
# - Come more **prepared** with the plan for presenting
# - Keep the presentation concise but informational

# %% [markdown]
# **Comments I enjoyed:**
# - Some CSA students really liked our interactive MCQs and fill in the blanks
# - Two parents made a verbal comment about how our vocab was good

# %% [markdown]
# If we had **more time**, I would like to add **more sports** options. This is because I think the more options the better. It also allows you to branch out to less known sports teams and deepen your sports knowledge.

# %% [markdown]
# ---

# %% [markdown]
# ## Future Learning

# %% [markdown]
# I would like to learn how to make more complicated games such as a **top down shooter game**. It would have **cool features** such as a shop, a complex map, and interesting enemies. I think this would be both fun to make and play, making it a cool project to do.

# %% [markdown]
# ---

# %% [markdown]
# ## MCQ Review

# %% [markdown]
# **Score:** = 38/66
#
# **Approach in taking the MCQ:**
# - Left unknown questions blank
# - Crossed out answers I knew weren't correct and narrowed down from there
#
# **Future:**
# - Work on areas I know I am struggling to understand
# - Identify why I got each question wrong
#
# **Missed questions:**
#
# 1. Q9
#
# 2. Q16
#
# 3. Q24
#
# 4. Q26
#
# 5. Q27
#
# 6. Q28
#
# 7. Q29
#
# 8. Q30
#
# 9. Q31
#
# 10. Q35
#
# 11. Q37
#
# 12. Q39
#
# 13. Q41
#
# 14. Q42
#
# 15. Q43
#
# 16. Q43
#
# 17. Q44
#
# 18. Q45
#
# 19. Q46
#
# 20. Q47
#
# 21. Q48
#
# 22. Q50
#
# 23. Q51
#
# 24. Q56
#
# 25. Q58
#
# 26. Q60
#
# 27. Q64
#
# 28. Q65
#
# 29. Q66

# %% [markdown]
# Strong concepts:
# - **2.3**: Extracting Information from Data
# - **3.2**: Variables and Assignments
# - **3.12**: Calling Procedures
#
# Concepts I need to improve in:
# - **2.1**: Binary Numbers
# - **3.17**: Algorithmic Efficieny
# - **5.5**: Legal and Ethical Concerns

# %% [markdown]
# ---

# %% [markdown]
# ## Coolest Achievement

# %% [markdown]
# My **coolest** achievement was creating the **MCQ** for the variables and strings lessons. I thought that it was a good idea and creating a competition out of it made it fun. I didn't think that any other group had a competitve componenet in their lessons so I think its cool that we did.
